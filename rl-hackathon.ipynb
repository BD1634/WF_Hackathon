# %% [markdown]
# ## Import libraries

# %%
import sys
sys.path.append('../input/iterativestratification/')

import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

import gc
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm

import re
import nltk
import string
from textblob import TextBlob
from nltk.corpus import stopwords

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import QuantileTransformer
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression

tqdm.pandas()
np.random.seed(42)
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## Load source datasets

# %%
train = pd.read_csv('../input/feedback-prize-english-language-learning/train.csv')
print(f"train: {train.shape}")
train.head()
# Out:
# train: (3911, 8)
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
test = pd.read_csv('../input/feedback-prize-english-language-learning/test.csv')
print(f"test: {test.shape}")
test.head()
# Out:
# test: (3, 2)
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
labels = ["cohesion", "syntax", "vocabulary", "phraseology", "grammar", "conventions"]
data_labels = train[labels].values

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Helper Functions

# %%
def contraction_count(sent):
    count = 0
    count += re.subn(r"won\'t", '', sent)[1]
    count += re.subn(r"can\'t", '', sent)[1]
    count += re.subn(r"n\'t", '', sent)[1]
    count += re.subn(r"\'re", '', sent)[1]
    count += re.subn(r"\'s", '', sent)[1]
    count += re.subn(r"\'d", '', sent)[1]
    count += re.subn(r"\'ll", '', sent)[1]
    count += re.subn(r"\'t", '', sent)[1]
    count += re.subn(r"\'ve", '', sent)[1]
    count += re.subn(r"\'m", '', sent)[1]
    return count

# %%
def decontraction(phrase):
    phrase = re.sub(r"won\'t", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    phrase = re.sub(r"he's", "he is", phrase)
    phrase = re.sub(r"there's", "there is", phrase)
    phrase = re.sub(r"We're", "We are", phrase)
    phrase = re.sub(r"That's", "That is", phrase)
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"they're", "they are", phrase)
    phrase = re.sub(r"Can't", "Cannot", phrase)
    phrase = re.sub(r"wasn't", "was not", phrase)
    phrase = re.sub(r"don\x89Ûªt", "do not", phrase)
    phrase = re.sub(r"donãât", "do not", phrase)
    phrase = re.sub(r"aren't", "are not", phrase)
    phrase = re.sub(r"isn't", "is not", phrase)
    phrase = re.sub(r"What's", "What is", phrase)
    phrase = re.sub(r"haven't", "have not", phrase)
    phrase = re.sub(r"hasn't", "has not", phrase)
    phrase = re.sub(r"There's", "There is", phrase)
    phrase = re.sub(r"He's", "He is", phrase)
    phrase = re.sub(r"It's", "It is", phrase)
    phrase = re.sub(r"You're", "You are", phrase)
    phrase = re.sub(r"I'M", "I am", phrase)
    phrase = re.sub(r"shouldn't", "should not", phrase)
    phrase = re.sub(r"wouldn't", "would not", phrase)
    phrase = re.sub(r"i'm", "I am", phrase)
    phrase = re.sub(r"I\x89Ûªm", "I am", phrase)
    phrase = re.sub(r"I'm", "I am", phrase)
    phrase = re.sub(r"Isn't", "is not", phrase)
    phrase = re.sub(r"Here's", "Here is", phrase)
    phrase = re.sub(r"you've", "you have", phrase)
    phrase = re.sub(r"you\x89Ûªve", "you have", phrase)
    phrase = re.sub(r"we're", "we are", phrase)
    phrase = re.sub(r"what's", "what is", phrase)
    phrase = re.sub(r"couldn't", "could not", phrase)
    phrase = re.sub(r"we've", "we have", phrase)
    phrase = re.sub(r"it\x89Ûªs", "it is", phrase)
    phrase = re.sub(r"doesn\x89Ûªt", "does not", phrase)
    phrase = re.sub(r"It\x89Ûªs", "It is", phrase)
    phrase = re.sub(r"Here\x89Ûªs", "Here is", phrase)
    phrase = re.sub(r"who's", "who is", phrase)
    phrase = re.sub(r"I\x89Ûªve", "I have", phrase)
    phrase = re.sub(r"y'all", "you all", phrase)
    phrase = re.sub(r"can\x89Ûªt", "cannot", phrase)
    phrase = re.sub(r"would've", "would have", phrase)
    phrase = re.sub(r"it'll", "it will", phrase)
    phrase = re.sub(r"we'll", "we will", phrase)
    phrase = re.sub(r"wouldn\x89Ûªt", "would not", phrase)
    phrase = re.sub(r"We've", "We have", phrase)
    phrase = re.sub(r"he'll", "he will", phrase)
    phrase = re.sub(r"Y'all", "You all", phrase)
    phrase = re.sub(r"Weren't", "Were not", phrase)
    phrase = re.sub(r"Didn't", "Did not", phrase)
    phrase = re.sub(r"they'll", "they will", phrase)
    phrase = re.sub(r"they'd", "they would", phrase)
    phrase = re.sub(r"DON'T", "DO NOT", phrase)
    phrase = re.sub(r"That\x89Ûªs", "That is", phrase)
    phrase = re.sub(r"they've", "they have", phrase)
    phrase = re.sub(r"i'd", "I would", phrase)
    phrase = re.sub(r"should've", "should have", phrase)
    phrase = re.sub(r"You\x89Ûªre", "You are", phrase)
    phrase = re.sub(r"where's", "where is", phrase)
    phrase = re.sub(r"Don\x89Ûªt", "Do not", phrase)
    phrase = re.sub(r"we'd", "we would", phrase)
    phrase = re.sub(r"i'll", "I will", phrase)
    phrase = re.sub(r"weren't", "were not", phrase)
    phrase = re.sub(r"They're", "They are", phrase)
    phrase = re.sub(r"Can\x89Ûªt", "Cannot", phrase)
    phrase = re.sub(r"you\x89Ûªll", "you will", phrase)
    phrase = re.sub(r"I\x89Ûªd", "I would", phrase)
    phrase = re.sub(r"let's", "let us", phrase)
    phrase = re.sub(r"it's", "it is", phrase)
    phrase = re.sub(r"can't", "cannot", phrase)
    phrase = re.sub(r"don't", "do not", phrase)
    phrase = re.sub(r"you're", "you are", phrase)
    phrase = re.sub(r"i've", "I have", phrase)
    phrase = re.sub(r"that's", "that is", phrase)
    phrase = re.sub(r"i'll", "I will", phrase)
    phrase = re.sub(r"doesn't", "does not",phrase)
    phrase = re.sub(r"i'd", "I would", phrase)
    phrase = re.sub(r"didn't", "did not", phrase)
    phrase = re.sub(r"ain't", "am not", phrase)
    phrase = re.sub(r"you'll", "you will", phrase)
    phrase = re.sub(r"I've", "I have", phrase)
    phrase = re.sub(r"Don't", "do not", phrase)
    phrase = re.sub(r"I'll", "I will", phrase)
    phrase = re.sub(r"I'd", "I would", phrase)
    phrase = re.sub(r"Let's", "Let us", phrase)
    phrase = re.sub(r"you'd", "You would", phrase)
    phrase = re.sub(r"It's", "It is", phrase)
    phrase = re.sub(r"Ain't", "am not", phrase)
    phrase = re.sub(r"Haven't", "Have not", phrase)
    phrase = re.sub(r"Could've", "Could have", phrase)
    phrase = re.sub(r"youve", "you have", phrase)  
    phrase = re.sub(r"donå«t", "do not", phrase)
    return phrase

# %%
def remove_punctuations(text):
    for punctuation in list(string.punctuation):
        text = text.replace(punctuation, '')
    return text

# %%
def clean_number(text):
    text = re.sub(r'(\d+)([a-zA-Z])', '\g<1> \g<2>', text)
    text = re.sub(r'(\d+) (th|st|nd|rd) ', '\g<1>\g<2> ', text)
    text = re.sub(r'(\d+),(\d+)', '\g<1>\g<2>', text)
    return text

# %%
def sent2vec(text):
    words = nltk.word_tokenize(text)
    words = [w for w in words if w.isalpha()]
    
    M = []
    for w in words:
        try:
            M.append(embeddings_index[w])
        except:
            M.append(embeddings_index['unk'])
            continue
    
    M = np.array(M)
    v = M.sum(axis=0)
    if type(v) != np.ndarray:
        return np.zeros(300)
    
    return v / np.sqrt((v ** 2).sum())

# %% [markdown]
# ### Create basic text features

# %%
def text_features(df, col):
    df[f"{col}_num_words"] = df[col].progress_apply(lambda x: len(str(x).split()))
    df[f"{col}_num_unique_words"] = df[col].progress_apply(lambda x: len(set(str(x).split())))
    df[f"{col}_num_chars"] = df[col].progress_apply(lambda x: len(str(x)))
    df[f"{col}_num_stopwords"] = df[col].progress_apply(lambda x: len([w for w in str(x).lower().split() if w in stopwords.words('english')]))
    df[f"{col}_num_punctuations"] = df[col].progress_apply(lambda x: len([c for c in str(x) if c in list(string.punctuation)]))
    df[f"{col}_num_words_upper"] = df[col].progress_apply(lambda x: len([w for w in str(x).split() if w.isupper()]))
    df[f"{col}_num_words_title"] = df[col].progress_apply(lambda x: len([w for w in str(x).split() if w.istitle()]))
    df[f"{col}_mean_word_len"] = df[col].progress_apply(lambda x: np.mean([len(w) for w in str(x).split()]))
    df[f"{col}_num_paragraphs"] = df[col].progress_apply(lambda x: len(x.split('\n')))
    df[f"{col}_num_contractions"] = df[col].progress_apply(contraction_count)
    df[f"{col}_polarity"] = df[col].progress_apply(lambda x: TextBlob(x).sentiment[0])
    df[f"{col}_subjectivity"] = df[col].progress_apply(lambda x: TextBlob(x).sentiment[1])
    return df

# %%
train = text_features(train, "full_text")
train.head()
# Out:
# 100%|██████████| 3911/3911 [00:00<00:00, 41039.05it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 16539.56it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 463636.50it/s]
# 100%|██████████| 3911/3911 [04:01<00:00, 16.18it/s]
# 100%|██████████| 3911/3911 [00:13<00:00, 296.81it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 14476.21it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 14002.22it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 7645.81it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 184301.32it/s]
# 100%|██████████| 3911/3911 [00:00<00:00, 28784.47it/s]
# 100%|██████████| 3911/3911 [00:12<00:00, 321.22it/s]
# 100%|██████████| 3911/3911 [00:12<00:00, 323.04it/s]
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions  full_text_num_words  \
# 0     3.5         3.0          3.0      4.0          3.0                  261
# 1     2.5         3.0          2.0      2.0          2.5                  533
# 2     3.5         3.0          3.0      3.0          2.5                  320
# 3     4.5         4.5          4.5      4.0          5.0                  728
# 4     3.0         3.0          3.0      2.5          2.5                  234
#
#    full_text_num_unique_words  full_text_num_chars  full_text_num_stopwords  \
# 0                         144                 1387                      129
# 1                         151                 2635                      311
# 2                         136                 1663                      177
# 3                         260                 3973                      420
# 4                         106                 1326                      122
#
#    full_text_num_punctuations  full_text_num_words_upper  \
# 0                          21                          1
# 1                          21                          2
# 2                          36                          9
# 3                         108                          9
# 4                           3                          0
#
#    full_text_num_words_title  full_text_mean_word_len  \
# 0                          3                 4.252874
# 1                         12                 3.936210
# 2                         27                 4.196875
# 3                         57                 4.447802
# 4                          3                 4.089744
#
#    full_text_num_paragraphs  full_text_num_contractions  full_text_polarity  \
# 0                         7                           2            0.103571
# 1                        11                           6            0.084853
# 2                         3                          15            0.037857
# 3                        15                          41            0.225062
# 4                         5                           0            0.200216
#
#    full_text_subjectivity
# 0                0.551190
# 1                0.530833
# 2                0.516468
# 3                0.608395
# 4                0.527706

# %%
test = text_features(test, "full_text")
test.head()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 2699.04it/s]
# 100%|██████████| 3/3 [00:00<00:00, 2263.11it/s]
# 100%|██████████| 3/3 [00:00<00:00, 3225.56it/s]
# 100%|██████████| 3/3 [00:00<00:00, 11.95it/s]
# 100%|██████████| 3/3 [00:00<00:00, 229.64it/s]
# 100%|██████████| 3/3 [00:00<00:00, 2952.35it/s]
# 100%|██████████| 3/3 [00:00<00:00, 3155.98it/s]
# 100%|██████████| 3/3 [00:00<00:00, 2533.81it/s]
# 100%|██████████| 3/3 [00:00<00:00, 5075.80it/s]
# 100%|██████████| 3/3 [00:00<00:00, 3708.49it/s]
# 100%|██████████| 3/3 [00:00<00:00, 254.97it/s]
# 100%|██████████| 3/3 [00:00<00:00, 262.65it/s]
#         text_id                                          full_text  \
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...
#
#    full_text_num_words  full_text_num_unique_words  full_text_num_chars  \
# 0                  835                         263                 4224
# 1                  386                         140                 2167
# 2                  442                         187                 2361
#
#    full_text_num_stopwords  full_text_num_punctuations  \
# 0                      454                          37
# 1                      207                          36
# 2                      244                          33
#
#    full_text_num_words_upper  full_text_num_words_title  \
# 0                          1                         25
# 1                          1                         11
# 2                          1                         11
#
#    full_text_mean_word_len  full_text_num_paragraphs  \
# 0                 4.053892                        11
# 1                 4.608808                         5
# 2                 4.332579                         9
#
#    full_text_num_contractions  full_text_polarity  full_text_subjectivity
# 0                           2            0.263041                0.492126
# 1                          20            0.182193                0.502193
# 2                           0            0.308210                0.516237

# %% [markdown]
# ### Text Preprocessing

# %%
def clean_text(text):
    text = decontraction(text)
    text = text.lower()
    text = re.sub(r'[^\w\s]','',text, re.UNICODE)
    text = remove_punctuations(text)
    text = clean_number(text)
    return text

# %%
train['full_text'] = train['full_text'].progress_apply(clean_text)
test['full_text'] = test['full_text'].progress_apply(clean_text)
# Out:
# 100%|██████████| 3911/3911 [00:02<00:00, 1505.44it/s]
# 100%|██████████| 3/3 [00:00<00:00, 1021.17it/s]

# %% [markdown]
# ### Glove Embeddings

# %%
with open("../input/nlp-word-embeddings/Glove_Embeddings.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
embeddings_index = processed_data['glove_embeddings_index']
print('Word vectors found: {}'.format(len(embeddings_index)))

del processed_data
gc.collect()
# Out:
# Word vectors found: 2196017
# 464

# %%
train.set_index('text_id', inplace=True)

glove_vec = [sent2vec(x) for x in tqdm(train["full_text"].values)]
col_list = ['glove_'+str(i) for i in range(300)]
glove_vec_df = pd.DataFrame(np.array(glove_vec), columns=col_list, index=train.index)
print(f"glove_vec_df: {glove_vec_df.shape}")

train = pd.merge(
    train, 
    glove_vec_df, 
    how="inner", 
    on="text_id", 
    sort=False
)

del glove_vec, glove_vec_df
gc.collect()

print(f"train: {train.shape}")
train.head()
# Out:
# 100%|██████████| 3911/3911 [00:09<00:00, 417.36it/s]
# glove_vec_df: (3911, 300)
# train: (3911, 319)
#                                                       full_text  cohesion  \
# text_id
# 0016926B079C  i think that students would benefit from learn...       3.5
# 0022683E9EA5  when a problem is a change you have to let it ...       2.5
# 00299B378633  dear principal\n\nif u change the school polic...       3.0
# 003885A45F42  the best time in life is when you become yours...       4.5
# 0049B1DF5CCC  small act of kindness can impact in other peop...       2.5
#
#               syntax  vocabulary  phraseology  grammar  conventions  \
# text_id
# 0016926B079C     3.5         3.0          3.0      4.0          3.0
# 0022683E9EA5     2.5         3.0          2.0      2.0          2.5
# 00299B378633     3.5         3.0          3.0      3.0          2.5
# 003885A45F42     4.5         4.5          4.5      4.0          5.0
# 0049B1DF5CCC     3.0         3.0          3.0      2.5          2.5
#
#               full_text_num_words  full_text_num_unique_words  \
# text_id
# 0016926B079C                  261                         144
# 0022683E9EA5                  533                         151
# 00299B378633                  320                         136
# 003885A45F42                  728                         260
# 0049B1DF5CCC                  234                         106
#
#               full_text_num_chars  ...  glove_290  glove_291  glove_292  \
# text_id                            ...
# 0016926B079C                 1387  ...  -0.047897   0.012196  -0.005005
# 0022683E9EA5                 2635  ...  -0.059975   0.013082  -0.006524
# 00299B378633                 1663  ...  -0.052307  -0.002266  -0.009439
# 003885A45F42                 3973  ...  -0.069191   0.011354  -0.025531
# 0049B1DF5CCC                 1326  ...  -0.065113   0.012299  -0.010551
#
#               glove_293  glove_294  glove_295  glove_296  glove_297  \
# text_id
# 0016926B079C  -0.018625   0.015539   0.000387  -0.024421  -0.015618
# 0022683E9EA5  -0.023567   0.032040  -0.003510  -0.023261  -0.011262
# 00299B378633  -0.032528   0.024091   0.001360  -0.040144  -0.038722
# 003885A45F42  -0.026579   0.024683   0.006697  -0.023632  -0.022341
# 0049B1DF5CCC  -0.035280   0.009560   0.012831  -0.013666  -0.018179
#
#               glove_298  glove_299
# text_id
# 0016926B079C   0.039680   0.028479
# 0022683E9EA5   0.033279   0.039578
# 00299B378633   0.042079   0.023270
# 003885A45F42   0.040106   0.026516
# 0049B1DF5CCC   0.016979   0.031928
#
# [5 rows x 319 columns]

# %%
test.set_index('text_id', inplace=True)

glove_vec = [sent2vec(x) for x in tqdm(test["full_text"].values)]
col_list = ['glove_'+str(i) for i in range(300)]
glove_vec_df = pd.DataFrame(np.array(glove_vec), columns=col_list, index=test.index)
print(f"glove_vec_df: {glove_vec_df.shape}")

test = pd.merge(
    test, 
    glove_vec_df, 
    how="inner", 
    on="text_id", 
    sort=False
)

del glove_vec, glove_vec_df
gc.collect()

print(f"test: {test.shape}")
test.head()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 268.49it/s]
# glove_vec_df: (3, 300)
# test: (3, 313)
#                                                       full_text  \
# text_id
# 0000C359D63E  when a person has no experience on a job their...
# 000BAD50D026  do you think students would benefit from being...
# 00367BB2546B  thomas jefferson once states that it is wonder...
#
#               full_text_num_words  full_text_num_unique_words  \
# text_id
# 0000C359D63E                  835                         263
# 000BAD50D026                  386                         140
# 00367BB2546B                  442                         187
#
#               full_text_num_chars  full_text_num_stopwords  \
# text_id
# 0000C359D63E                 4224                      454
# 000BAD50D026                 2167                      207
# 00367BB2546B                 2361                      244
#
#               full_text_num_punctuations  full_text_num_words_upper  \
# text_id
# 0000C359D63E                          37                          1
# 000BAD50D026                          36                          1
# 00367BB2546B                          33                          1
#
#               full_text_num_words_title  full_text_mean_word_len  \
# text_id
# 0000C359D63E                         25                 4.053892
# 000BAD50D026                         11                 4.608808
# 00367BB2546B                         11                 4.332579
#
#               full_text_num_paragraphs  ...  glove_290  glove_291  glove_292  \
# text_id                                 ...
# 0000C359D63E                        11  ...  -0.051433   0.007779  -0.016645
# 000BAD50D026                         5  ...  -0.023414  -0.001185  -0.001112
# 00367BB2546B                         9  ...  -0.054315   0.019050  -0.012756
#
#               glove_293  glove_294  glove_295  glove_296  glove_297  \
# text_id
# 0000C359D63E  -0.031097   0.028537  -0.002610  -0.027199  -0.017325
# 000BAD50D026  -0.006998   0.014711   0.003211  -0.024542  -0.025076
# 00367BB2546B  -0.022174   0.019773  -0.015299  -0.026611  -0.018428
#
#               glove_298  glove_299
# text_id
# 0000C359D63E   0.027618   0.032211
# 000BAD50D026   0.029015   0.018912
# 00367BB2546B   0.035217   0.029322
#
# [3 rows x 313 columns]

# %%
del embeddings_index
gc.collect()
# Out:
# 24

# %% [markdown]
# ### FastText Embeddings

# %%
with open("../input/nlp-word-embeddings/FastText_Embeddings.txt", 'rb') as handle: 
    data = handle.read()

processed_data = pickle.loads(data)
embeddings_index = processed_data['fasttext_embeddings_index']
print('Word vectors found: {}'.format(len(embeddings_index)))

del processed_data
gc.collect()
# Out:
# Word vectors found: 1000000
# 0

# %%
fasttext_vec = [sent2vec(x) for x in tqdm(train["full_text"].values)]
col_list = ['fasttext_'+str(i) for i in range(300)]
fasttext_vec_df = pd.DataFrame(np.array(fasttext_vec), columns=col_list, index=train.index)
print(f"fasttext_vec_df: {fasttext_vec_df.shape}")

train = pd.merge(
    train, 
    fasttext_vec_df, 
    how="inner", 
    on="text_id", 
    sort=False
)

del fasttext_vec, fasttext_vec_df
gc.collect()

train.drop('full_text', axis=1, inplace=True)
print(f"train: {train.shape}")
train.head()
# Out:
# 100%|██████████| 3911/3911 [00:10<00:00, 368.32it/s]
# fasttext_vec_df: (3911, 300)
# train: (3911, 618)
#               cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# text_id
# 0016926B079C       3.5     3.5         3.0          3.0      4.0          3.0
# 0022683E9EA5       2.5     2.5         3.0          2.0      2.0          2.5
# 00299B378633       3.0     3.5         3.0          3.0      3.0          2.5
# 003885A45F42       4.5     4.5         4.5          4.5      4.0          5.0
# 0049B1DF5CCC       2.5     3.0         3.0          3.0      2.5          2.5
#
#               full_text_num_words  full_text_num_unique_words  \
# text_id
# 0016926B079C                  261                         144
# 0022683E9EA5                  533                         151
# 00299B378633                  320                         136
# 003885A45F42                  728                         260
# 0049B1DF5CCC                  234                         106
#
#               full_text_num_chars  full_text_num_stopwords  ...  fasttext_290  \
# text_id                                                     ...
# 0016926B079C                 1387                      129  ...      0.003124
# 0022683E9EA5                 2635                      311  ...      0.015170
# 00299B378633                 1663                      177  ...      0.009466
# 003885A45F42                 3973                      420  ...      0.013575
# 0049B1DF5CCC                 1326                      122  ...      0.010878
#
#               fasttext_291  fasttext_292  fasttext_293  fasttext_294  \
# text_id
# 0016926B079C     -0.004187     -0.008275      0.004614      0.006928
# 0022683E9EA5     -0.001463     -0.005018      0.003173     -0.006586
# 00299B378633     -0.007042     -0.013316      0.001678     -0.004676
# 003885A45F42     -0.009068     -0.014698     -0.003738     -0.001768
# 0049B1DF5CCC     -0.017811     -0.000063     -0.008606     -0.008423
#
#               fasttext_295  fasttext_296  fasttext_297  fasttext_298  \
# text_id
# 0016926B079C      0.000480     -0.014724      0.152922      0.012428
# 0022683E9EA5     -0.015554     -0.025787      0.164027      0.023467
# 00299B378633      0.007161     -0.016156      0.141131      0.017130
# 003885A45F42     -0.015897     -0.030869      0.165310      0.004362
# 0049B1DF5CCC     -0.017439     -0.026796      0.160969      0.002208
#
#               fasttext_299
# text_id
# 0016926B079C      0.005484
# 0022683E9EA5     -0.000588
# 00299B378633     -0.013145
# 003885A45F42     -0.012372
# 0049B1DF5CCC      0.006025
#
# [5 rows x 618 columns]

# %%
fasttext_vec = [sent2vec(x) for x in tqdm(test["full_text"].values)]
col_list = ['fasttext_'+str(i) for i in range(300)]
fasttext_vec_df = pd.DataFrame(np.array(fasttext_vec), columns=col_list, index=test.index)
print(f"fasttext_vec_df: {fasttext_vec_df.shape}")

test = pd.merge(
    test, 
    fasttext_vec_df, 
    how="inner", 
    on="text_id", 
    sort=False
)

del fasttext_vec, fasttext_vec_df
gc.collect()

test.drop('full_text', axis=1, inplace=True)
print(f"test: {test.shape}")
test.head()
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 245.99it/s]
# fasttext_vec_df: (3, 300)
# test: (3, 612)
#               full_text_num_words  full_text_num_unique_words  \
# text_id
# 0000C359D63E                  835                         263
# 000BAD50D026                  386                         140
# 00367BB2546B                  442                         187
#
#               full_text_num_chars  full_text_num_stopwords  \
# text_id
# 0000C359D63E                 4224                      454
# 000BAD50D026                 2167                      207
# 00367BB2546B                 2361                      244
#
#               full_text_num_punctuations  full_text_num_words_upper  \
# text_id
# 0000C359D63E                          37                          1
# 000BAD50D026                          36                          1
# 00367BB2546B                          33                          1
#
#               full_text_num_words_title  full_text_mean_word_len  \
# text_id
# 0000C359D63E                         25                 4.053892
# 000BAD50D026                         11                 4.608808
# 00367BB2546B                         11                 4.332579
#
#               full_text_num_paragraphs  full_text_num_contractions  ...  \
# text_id                                                             ...
# 0000C359D63E                        11                           2  ...
# 000BAD50D026                         5                          20  ...
# 00367BB2546B                         9                           0  ...
#
#               fasttext_290  fasttext_291  fasttext_292  fasttext_293  \
# text_id
# 0000C359D63E      0.007568     -0.011315     -0.017608     -0.002028
# 000BAD50D026     -0.000962     -0.020579     -0.001811      0.000838
# 00367BB2546B      0.014041     -0.002292     -0.020868      0.001919
#
#               fasttext_294  fasttext_295  fasttext_296  fasttext_297  \
# text_id
# 0000C359D63E      0.003305     -0.004966     -0.025996      0.160157
# 000BAD50D026      0.004391      0.017770     -0.027009      0.124490
# 00367BB2546B     -0.015535     -0.013856     -0.022666      0.164269
#
#               fasttext_298  fasttext_299
# text_id
# 0000C359D63E      0.011031     -0.009291
# 000BAD50D026      0.002267      0.007213
# 00367BB2546B      0.008171     -0.008842
#
# [3 rows x 612 columns]

# %%
del embeddings_index
gc.collect()
# Out:
# 24

# %%
features = test.columns.tolist()

qt = QuantileTransformer(n_quantiles=1000, 
                         output_distribution='normal', 
                         random_state=42).fit(train[features])

train[features] = qt.transform(train[features])
test[features] = qt.transform(test[features])

# %% [markdown]
# ## Models Training

# %% [markdown]
# ### XGBoost

# %%
counter = 0
oof_score = 0
y_pred_final_xgb = np.zeros((test.shape[0], 6))

    
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(mskf.split(train, data_labels)):
    counter += 1

    train_x, val_x = train.iloc[train_idx][features], train.iloc[val_idx][features]
    
    mean_score = 0
    for i in range(len(labels)):
        train_y, val_y = train.iloc[train_idx][labels[i]], train.iloc[val_idx][labels[i]]

        model = XGBRegressor(
            objective='reg:squarederror',
            eval_metric='rmse',
            booster='gbtree',
            sample_type='weighted',
            tree_method='hist',
            grow_policy='lossguide',
            use_label_encoder=False,
            num_round=5000,
            max_depth=9, 
            max_leaves=36,
            learning_rate=0.095,
            subsample=0.7024,
            colsample_bytree=0.5289,
            min_child_weight=15,
            reg_lambda=0.05465,
            verbosity=0,
            random_state=42
        )
        
        model.fit(train_x, train_y, eval_set=[(train_x, train_y), (val_x, val_y)], 
                  early_stopping_rounds=100, verbose=50)
    
        y_pred = model.predict(val_x, iteration_range=(0, model.best_iteration))
        y_pred_final_xgb[:,i] += model.predict(test[features], iteration_range=(0, model.best_iteration))
    
        score = np.sqrt(mean_squared_error(val_y, y_pred))
        print(f"Fold-{counter} | Col-{labels[i]} | RMSE Score: {score}")
        mean_score += score/float(len(labels))
    
    
    oof_score += mean_score
    print(f"\nFold-{counter} | OOF Score: {mean_score}\n\n")
    
    del model, y_pred
    del train_x, train_y
    del val_x, val_y
    gc.collect()


y_pred_final_xgb = y_pred_final_xgb / float(counter)
oof_score /= float(counter)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# [0]	validation_0-rmse:2.47475	validation_1-rmse:2.41365
# [50]	validation_0-rmse:0.28840	validation_1-rmse:0.54842
# [99]	validation_0-rmse:0.16359	validation_1-rmse:0.54888
# Fold-1 | Col-cohesion | RMSE Score: 0.5473253091490693
# [0]	validation_0-rmse:2.38587	validation_1-rmse:2.31828
# [50]	validation_0-rmse:0.28300	validation_1-rmse:0.53819
# [99]	validation_0-rmse:0.15908	validation_1-rmse:0.53929
# Fold-1 | Col-syntax | RMSE Score: 0.537687406819246
# [0]	validation_0-rmse:2.54708	validation_1-rmse:2.50897
# [50]	validation_0-rmse:0.24668	validation_1-rmse:0.46684
# [99]	validation_0-rmse:0.14235	validation_1-rmse:0.46900
# Fold-1 | Col-vocabulary | RMSE Score: 0.4665429537842513
# [0]	validation_0-rmse:2.46448	validation_1-rmse:2.40254
# [50]	validation_0-rmse:0.28490	validation_1-rmse:0.54076
# [99]	validation_0-rmse:0.15924	validation_1-rmse:0.54077
# Fold-1 | Col-phraseology | RMSE Score: 0.5396945513598742
# [0]	validation_0-rmse:2.40977	validation_1-rmse:2.31801
# [50]	validation_0-rmse:0.30970	validation_1-rmse:0.59417
# [99]	validation_0-rmse:0.17303	validation_1-rmse:0.59507
# Fold-1 | Col-grammar | RMSE Score: 0.5910050204652225
# [0]	validation_0-rmse:2.43357	validation_1-rmse:2.38096
# [50]	validation_0-rmse:0.27672	validation_1-rmse:0.52803
# [99]	validation_0-rmse:0.15762	validation_1-rmse:0.53126
# Fold-1 | Col-conventions | RMSE Score: 0.5268511310124682
#
# Fold-1 | OOF Score: 0.5348510620983552
#
#
# [0]	validation_0-rmse:2.46407	validation_1-rmse:2.46024
# [50]	validation_0-rmse:0.28744	validation_1-rmse:0.55462
# [99]	validation_0-rmse:0.16199	validation_1-rmse:0.55424
# Fold-2 | Col-cohesion | RMSE Score: 0.5525226987939241
# [0]	validation_0-rmse:2.37676	validation_1-rmse:2.35400
# [50]	validation_0-rmse:0.27860	validation_1-rmse:0.54626
# [99]	validation_0-rmse:0.15691	validation_1-rmse:0.54548
# Fold-2 | Col-syntax | RMSE Score: 0.545138704314946
# [0]	validation_0-rmse:2.54229	validation_1-rmse:2.52803
# [50]	validation_0-rmse:0.24657	validation_1-rmse:0.47924
# [99]	validation_0-rmse:0.14201	validation_1-rmse:0.47706
# Fold-2 | Col-vocabulary | RMSE Score: 0.4766550750125673
# [0]	validation_0-rmse:2.45312	validation_1-rmse:2.44769
# [50]	validation_0-rmse:0.28002	validation_1-rmse:0.55998
# [99]	validation_0-rmse:0.15853	validation_1-rmse:0.56160
# Fold-2 | Col-phraseology | RMSE Score: 0.557913114965335
# [0]	validation_0-rmse:2.39702	validation_1-rmse:2.37473
# [50]	validation_0-rmse:0.31129	validation_1-rmse:0.58829
# [99]	validation_0-rmse:0.17655	validation_1-rmse:0.58571
# Fold-2 | Col-grammar | RMSE Score: 0.5851681502333966
# [0]	validation_0-rmse:2.42470	validation_1-rmse:2.42113
# [50]	validation_0-rmse:0.27451	validation_1-rmse:0.54325
# [99]	validation_0-rmse:0.15487	validation_1-rmse:0.54531
# Fold-2 | Col-conventions | RMSE Score: 0.5425898674222267
#
# Fold-2 | OOF Score: 0.5433312684570659
#
#
# [0]	validation_0-rmse:2.45835	validation_1-rmse:2.48176
# [50]	validation_0-rmse:0.28967	validation_1-rmse:0.57729
# [99]	validation_0-rmse:0.16626	validation_1-rmse:0.57789
# Fold-3 | Col-cohesion | RMSE Score: 0.5766559632869646
# [0]	validation_0-rmse:2.36252	validation_1-rmse:2.41479
# [50]	validation_0-rmse:0.27762	validation_1-rmse:0.54508
# [99]	validation_0-rmse:0.16018	validation_1-rmse:0.54849
# Fold-3 | Col-syntax | RMSE Score: 0.5451169072663865
# [0]	validation_0-rmse:2.53491	validation_1-rmse:2.56306
# [50]	validation_0-rmse:0.24607	validation_1-rmse:0.47644
# [99]	validation_0-rmse:0.13953	validation_1-rmse:0.47973
# Fold-3 | Col-vocabulary | RMSE Score: 0.4764418123167489
# [0]	validation_0-rmse:2.44918	validation_1-rmse:2.47047
# [50]	validation_0-rmse:0.28688	validation_1-rmse:0.52855
# [99]	validation_0-rmse:0.16054	validation_1-rmse:0.53168
# Fold-3 | Col-phraseology | RMSE Score: 0.5285491456762408
# [0]	validation_0-rmse:2.38140	validation_1-rmse:2.42920
# [50]	validation_0-rmse:0.30774	validation_1-rmse:0.60736
# [99]	validation_0-rmse:0.17263	validation_1-rmse:0.60784
# Fold-3 | Col-grammar | RMSE Score: 0.6066202690714877
# [0]	validation_0-rmse:2.41582	validation_1-rmse:2.46147
# [50]	validation_0-rmse:0.27920	validation_1-rmse:0.54074
# [99]	validation_0-rmse:0.15850	validation_1-rmse:0.53715
# Fold-3 | Col-conventions | RMSE Score: 0.5371543038614122
#
# Fold-3 | OOF Score: 0.5450897335798734
#
#
# [0]	validation_0-rmse:2.46075	validation_1-rmse:2.46967
# [50]	validation_0-rmse:0.29153	validation_1-rmse:0.55082
# [99]	validation_0-rmse:0.16398	validation_1-rmse:0.55416
# Fold-4 | Col-cohesion | RMSE Score: 0.5492335200707641
# [0]	validation_0-rmse:2.36759	validation_1-rmse:2.39130
# [50]	validation_0-rmse:0.28072	validation_1-rmse:0.54129
# [99]	validation_0-rmse:0.16011	validation_1-rmse:0.53950
# Fold-4 | Col-syntax | RMSE Score: 0.5383102376072727
# [0]	validation_0-rmse:2.53578	validation_1-rmse:2.55517
# [50]	validation_0-rmse:0.24258	validation_1-rmse:0.49362
# [99]	validation_0-rmse:0.13653	validation_1-rmse:0.49174
# Fold-4 | Col-vocabulary | RMSE Score: 0.49149098044926215
# [0]	validation_0-rmse:2.45059	validation_1-rmse:2.46645
# [50]	validation_0-rmse:0.28283	validation_1-rmse:0.54956
# [99]	validation_0-rmse:0.15936	validation_1-rmse:0.55239
# Fold-4 | Col-phraseology | RMSE Score: 0.5490216140121933
# [0]	validation_0-rmse:2.38888	validation_1-rmse:2.40714
# [50]	validation_0-rmse:0.30682	validation_1-rmse:0.61643
# [99]	validation_0-rmse:0.17720	validation_1-rmse:0.61741
# Fold-4 | Col-grammar | RMSE Score: 0.6131845061491478
# [0]	validation_0-rmse:2.42603	validation_1-rmse:2.41593
# [50]	validation_0-rmse:0.27822	validation_1-rmse:0.52462
# [99]	validation_0-rmse:0.15919	validation_1-rmse:0.52359
# Fold-4 | Col-conventions | RMSE Score: 0.5226337045343562
#
# Fold-4 | OOF Score: 0.5439790938038327
#
#
# [0]	validation_0-rmse:2.45555	validation_1-rmse:2.49845
# [50]	validation_0-rmse:0.29104	validation_1-rmse:0.55039
# [99]	validation_0-rmse:0.16493	validation_1-rmse:0.54573
# Fold-5 | Col-cohesion | RMSE Score: 0.5459482283043451
# [0]	validation_0-rmse:2.36758	validation_1-rmse:2.39059
# [50]	validation_0-rmse:0.28410	validation_1-rmse:0.53676
# [99]	validation_0-rmse:0.16231	validation_1-rmse:0.53901
# Fold-5 | Col-syntax | RMSE Score: 0.536184817126764
# [0]	validation_0-rmse:2.53772	validation_1-rmse:2.55021
# [50]	validation_0-rmse:0.24608	validation_1-rmse:0.47146
# [99]	validation_0-rmse:0.14013	validation_1-rmse:0.47160
# Fold-5 | Col-vocabulary | RMSE Score: 0.4701063316380898
# [0]	validation_0-rmse:2.44478	validation_1-rmse:2.48137
# [50]	validation_0-rmse:0.28639	validation_1-rmse:0.54975
# [99]	validation_0-rmse:0.16135	validation_1-rmse:0.54937
# Fold-5 | Col-phraseology | RMSE Score: 0.5482345605227832
# [0]	validation_0-rmse:2.38040	validation_1-rmse:2.43986
# [50]	validation_0-rmse:0.30676	validation_1-rmse:0.59749
# [99]	validation_0-rmse:0.17335	validation_1-rmse:0.59212
# Fold-5 | Col-grammar | RMSE Score: 0.5927488232845802
# [0]	validation_0-rmse:2.41994	validation_1-rmse:2.44429
# [50]	validation_0-rmse:0.28125	validation_1-rmse:0.52260
# [99]	validation_0-rmse:0.16009	validation_1-rmse:0.51612
# Fold-5 | Col-conventions | RMSE Score: 0.5158154559317016
#
# Fold-5 | OOF Score: 0.5348397028013774
#
#
# Aggregate OOF Score: 0.540418172148101

# %% [markdown]
# ### LightGBM

# %%
counter = 0
oof_score = 0
y_pred_final_lgb = np.zeros((test.shape[0], 6))

    
mskf = MultilabelStratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(mskf.split(train, data_labels)):
    counter += 1

    train_x, val_x = train.iloc[train_idx][features], train.iloc[val_idx][features]
    
    mean_score = 0
    for i in range(len(labels)):
        train_y, val_y = train.iloc[train_idx][labels[i]], train.iloc[val_idx][labels[i]]

        model = LGBMRegressor(
            boosting_type='gbdt', 
            num_leaves=175, 
            max_depth=9, 
            learning_rate=0.05, 
            n_estimators=5000,
            objective='regression',
            min_child_samples=5, 
            subsample=0.85, 
            subsample_freq=5, 
            colsample_bytree=0.55, 
            reg_lambda=0.05,
            random_state=0,
            bagging_seed=0,
            feature_fraction_seed=0
        )
        
        model.fit(train_x, train_y, eval_metric='rmse',
                  eval_set=[(train_x, train_y), (val_x, val_y)],
                  early_stopping_rounds=100, verbose=100)
    
        y_pred = model.predict(val_x, num_iteration=model.best_iteration_)
        y_pred_final_lgb[:,i] += model.predict(test[features], num_iteration=model.best_iteration_)
    
        score = np.sqrt(mean_squared_error(val_y, y_pred))
        print(f"Fold-{counter} | Col-{labels[i]} | RMSE Score: {score}")
        mean_score += score/float(len(labels))
    
    
    oof_score += mean_score
    print(f"\nFold-{counter} | OOF Score: {mean_score}\n\n")
    
    del model, y_pred
    del train_x, train_y
    del val_x, val_y
    gc.collect()


y_pred_final_lgb = y_pred_final_lgb / float(counter)
oof_score /= float(counter)
print("Aggregate OOF Score: {}".format(oof_score))
# Out:
# [100]	training's rmse: 0.0835898	training's l2: 0.00698725	valid_1's rmse: 0.547678	valid_1's l2: 0.299951
# [200]	training's rmse: 0.0143904	training's l2: 0.000207085	valid_1's rmse: 0.547177	valid_1's l2: 0.299403
# [300]	training's rmse: 0.00300559	training's l2: 9.03359e-06	valid_1's rmse: 0.54701	valid_1's l2: 0.29922
# [400]	training's rmse: 0.000952217	training's l2: 9.06717e-07	valid_1's rmse: 0.547002	valid_1's l2: 0.299212
# Fold-1 | Col-cohesion | RMSE Score: 0.5469858296080827
# [100]	training's rmse: 0.0774156	training's l2: 0.00599317	valid_1's rmse: 0.531931	valid_1's l2: 0.282951
# [200]	training's rmse: 0.0138761	training's l2: 0.000192546	valid_1's rmse: 0.531521	valid_1's l2: 0.282514
# Fold-1 | Col-syntax | RMSE Score: 0.5314830417946587
# [100]	training's rmse: 0.0679072	training's l2: 0.00461139	valid_1's rmse: 0.463387	valid_1's l2: 0.214728
# [200]	training's rmse: 0.0113637	training's l2: 0.000129134	valid_1's rmse: 0.462448	valid_1's l2: 0.213858
# Fold-1 | Col-vocabulary | RMSE Score: 0.4623008655219792
# [100]	training's rmse: 0.0720838	training's l2: 0.00519607	valid_1's rmse: 0.542934	valid_1's l2: 0.294777
# [200]	training's rmse: 0.0121261	training's l2: 0.000147042	valid_1's rmse: 0.542202	valid_1's l2: 0.293983
# Fold-1 | Col-phraseology | RMSE Score: 0.5418819586665621
# [100]	training's rmse: 0.0809951	training's l2: 0.0065602	valid_1's rmse: 0.590762	valid_1's l2: 0.349
# [200]	training's rmse: 0.0140701	training's l2: 0.000197969	valid_1's rmse: 0.589789	valid_1's l2: 0.347851
# [300]	training's rmse: 0.00316756	training's l2: 1.00334e-05	valid_1's rmse: 0.589809	valid_1's l2: 0.347875
# Fold-1 | Col-grammar | RMSE Score: 0.5897523435499217
# [100]	training's rmse: 0.0719047	training's l2: 0.00517028	valid_1's rmse: 0.540286	valid_1's l2: 0.291909
# [200]	training's rmse: 0.0133902	training's l2: 0.000179297	valid_1's rmse: 0.538286	valid_1's l2: 0.289752
# [300]	training's rmse: 0.00273376	training's l2: 7.47342e-06	valid_1's rmse: 0.538221	valid_1's l2: 0.289682
# Fold-1 | Col-conventions | RMSE Score: 0.538196456413067
#
# Fold-1 | OOF Score: 0.5351000825923786
#
#
# [100]	training's rmse: 0.0823894	training's l2: 0.00678802	valid_1's rmse: 0.559596	valid_1's l2: 0.313148
# [200]	training's rmse: 0.0135986	training's l2: 0.000184922	valid_1's rmse: 0.557918	valid_1's l2: 0.311272
# [300]	training's rmse: 0.00240299	training's l2: 5.77436e-06	valid_1's rmse: 0.557678	valid_1's l2: 0.311005
# Fold-2 | Col-cohesion | RMSE Score: 0.5576557903237203
# [100]	training's rmse: 0.076045	training's l2: 0.00578284	valid_1's rmse: 0.539957	valid_1's l2: 0.291554
# [200]	training's rmse: 0.0148503	training's l2: 0.000220533	valid_1's rmse: 0.538307	valid_1's l2: 0.289775
# Fold-2 | Col-syntax | RMSE Score: 0.5382458314547376
# [100]	training's rmse: 0.069079	training's l2: 0.0047719	valid_1's rmse: 0.469074	valid_1's l2: 0.220031
# [200]	training's rmse: 0.0146275	training's l2: 0.000213963	valid_1's rmse: 0.467822	valid_1's l2: 0.218858
# [300]	training's rmse: 0.00468736	training's l2: 2.19714e-05	valid_1's rmse: 0.467789	valid_1's l2: 0.218827
# Fold-2 | Col-vocabulary | RMSE Score: 0.46773515099033597
# [100]	training's rmse: 0.075007	training's l2: 0.00562605	valid_1's rmse: 0.559412	valid_1's l2: 0.312942
# [200]	training's rmse: 0.0120106	training's l2: 0.000144253	valid_1's rmse: 0.55747	valid_1's l2: 0.310772
# [300]	training's rmse: 0.00230811	training's l2: 5.32739e-06	valid_1's rmse: 0.557374	valid_1's l2: 0.310666
# [400]	training's rmse: 0.000681106	training's l2: 4.63905e-07	valid_1's rmse: 0.557361	valid_1's l2: 0.310651
# Fold-2 | Col-phraseology | RMSE Score: 0.557358144219918
# [100]	training's rmse: 0.0819375	training's l2: 0.00671376	valid_1's rmse: 0.59028	valid_1's l2: 0.348431
# [200]	training's rmse: 0.0142229	training's l2: 0.000202291	valid_1's rmse: 0.588025	valid_1's l2: 0.345774
# [300]	training's rmse: 0.00317351	training's l2: 1.00711e-05	valid_1's rmse: 0.587909	valid_1's l2: 0.345637
# [400]	training's rmse: 0.000928003	training's l2: 8.61189e-07	valid_1's rmse: 0.587861	valid_1's l2: 0.34558
# [500]	training's rmse: 0.0003652	training's l2: 1.33371e-07	valid_1's rmse: 0.587856	valid_1's l2: 0.345575
# Fold-2 | Col-grammar | RMSE Score: 0.5878554610949805
# [100]	training's rmse: 0.0670105	training's l2: 0.00449041	valid_1's rmse: 0.552408	valid_1's l2: 0.305154
# [200]	training's rmse: 0.0134822	training's l2: 0.00018177	valid_1's rmse: 0.551743	valid_1's l2: 0.30442
# Fold-2 | Col-conventions | RMSE Score: 0.5516126093780716
#
# Fold-2 | OOF Score: 0.543410497910294
#
#
# [100]	training's rmse: 0.0779076	training's l2: 0.0060696	valid_1's rmse: 0.569786	valid_1's l2: 0.324656
# [200]	training's rmse: 0.0133618	training's l2: 0.000178539	valid_1's rmse: 0.568195	valid_1's l2: 0.322845
# Fold-3 | Col-cohesion | RMSE Score: 0.5680071351160757
# [100]	training's rmse: 0.0729976	training's l2: 0.00532865	valid_1's rmse: 0.550007	valid_1's l2: 0.302507
# [200]	training's rmse: 0.0127686	training's l2: 0.000163038	valid_1's rmse: 0.550005	valid_1's l2: 0.302506
# Fold-3 | Col-syntax | RMSE Score: 0.5498526772786427
# [100]	training's rmse: 0.0659562	training's l2: 0.00435022	valid_1's rmse: 0.468924	valid_1's l2: 0.21989
# [200]	training's rmse: 0.0140301	training's l2: 0.000196844	valid_1's rmse: 0.468318	valid_1's l2: 0.219322
# [300]	training's rmse: 0.00445125	training's l2: 1.98136e-05	valid_1's rmse: 0.468377	valid_1's l2: 0.219377
# Fold-3 | Col-vocabulary | RMSE Score: 0.46824321130405594
# [100]	training's rmse: 0.0757006	training's l2: 0.00573058	valid_1's rmse: 0.535604	valid_1's l2: 0.286871
# [200]	training's rmse: 0.0143492	training's l2: 0.000205901	valid_1's rmse: 0.53358	valid_1's l2: 0.284707
# [300]	training's rmse: 0.00351256	training's l2: 1.23381e-05	valid_1's rmse: 0.533453	valid_1's l2: 0.284573
# Fold-3 | Col-phraseology | RMSE Score: 0.5333976380105818
# [100]	training's rmse: 0.0786269	training's l2: 0.00618218	valid_1's rmse: 0.608843	valid_1's l2: 0.37069
# [200]	training's rmse: 0.013384	training's l2: 0.000179132	valid_1's rmse: 0.607145	valid_1's l2: 0.368625
# [300]	training's rmse: 0.00241296	training's l2: 5.82237e-06	valid_1's rmse: 0.606924	valid_1's l2: 0.368356
# [400]	training's rmse: 0.000547975	training's l2: 3.00276e-07	valid_1's rmse: 0.606876	valid_1's l2: 0.368298
# Fold-3 | Col-grammar | RMSE Score: 0.6068714927494361
# [100]	training's rmse: 0.0691013	training's l2: 0.00477498	valid_1's rmse: 0.548694	valid_1's l2: 0.301065
# [200]	training's rmse: 0.0109288	training's l2: 0.000119438	valid_1's rmse: 0.547791	valid_1's l2: 0.300075
# Fold-3 | Col-conventions | RMSE Score: 0.5477381893101905
#
# Fold-3 | OOF Score: 0.5456850572948304
#
#
# [100]	training's rmse: 0.08854	training's l2: 0.00783934	valid_1's rmse: 0.557255	valid_1's l2: 0.310533
# [200]	training's rmse: 0.0183311	training's l2: 0.000336028	valid_1's rmse: 0.555908	valid_1's l2: 0.309034
# [300]	training's rmse: 0.00475743	training's l2: 2.26332e-05	valid_1's rmse: 0.555971	valid_1's l2: 0.309104
# Fold-4 | Col-cohesion | RMSE Score: 0.5558237198165644
# [100]	training's rmse: 0.0751364	training's l2: 0.00564547	valid_1's rmse: 0.543582	valid_1's l2: 0.295481
# [200]	training's rmse: 0.0131598	training's l2: 0.00017318	valid_1's rmse: 0.542996	valid_1's l2: 0.294845
# Fold-4 | Col-syntax | RMSE Score: 0.5426559115791909
# [100]	training's rmse: 0.0676406	training's l2: 0.00457526	valid_1's rmse: 0.491471	valid_1's l2: 0.241543
# [200]	training's rmse: 0.0123264	training's l2: 0.000151939	valid_1's rmse: 0.490349	valid_1's l2: 0.240442
# [300]	training's rmse: 0.00373674	training's l2: 1.39632e-05	valid_1's rmse: 0.490157	valid_1's l2: 0.240254
# [400]	training's rmse: 0.00157695	training's l2: 2.48677e-06	valid_1's rmse: 0.490156	valid_1's l2: 0.240253
# Fold-4 | Col-vocabulary | RMSE Score: 0.4901397461513223
# [100]	training's rmse: 0.0737034	training's l2: 0.00543219	valid_1's rmse: 0.546989	valid_1's l2: 0.299197
# [200]	training's rmse: 0.0129754	training's l2: 0.00016836	valid_1's rmse: 0.546383	valid_1's l2: 0.298535
# [300]	training's rmse: 0.00335215	training's l2: 1.12369e-05	valid_1's rmse: 0.546331	valid_1's l2: 0.298477
# [400]	training's rmse: 0.00113376	training's l2: 1.28542e-06	valid_1's rmse: 0.546308	valid_1's l2: 0.298452
# [500]	training's rmse: 0.000511077	training's l2: 2.612e-07	valid_1's rmse: 0.546303	valid_1's l2: 0.298447
# [600]	training's rmse: 0.000263745	training's l2: 6.95615e-08	valid_1's rmse: 0.546296	valid_1's l2: 0.298439
# [700]	training's rmse: 0.000164257	training's l2: 2.69802e-08	valid_1's rmse: 0.546292	valid_1's l2: 0.298435
# [800]	training's rmse: 9.07107e-05	training's l2: 8.22843e-09	valid_1's rmse: 0.54629	valid_1's l2: 0.298433
# [900]	training's rmse: 5.51839e-05	training's l2: 3.04527e-09	valid_1's rmse: 0.54629	valid_1's l2: 0.298433
# Fold-4 | Col-phraseology | RMSE Score: 0.5462900797572189
# [100]	training's rmse: 0.0858399	training's l2: 0.00736849	valid_1's rmse: 0.620718	valid_1's l2: 0.385291
# [200]	training's rmse: 0.0157162	training's l2: 0.000246999	valid_1's rmse: 0.618657	valid_1's l2: 0.382736
# Fold-4 | Col-grammar | RMSE Score: 0.6185168216485065
# [100]	training's rmse: 0.0714178	training's l2: 0.0051005	valid_1's rmse: 0.524193	valid_1's l2: 0.274779
# [200]	training's rmse: 0.0127743	training's l2: 0.000163184	valid_1's rmse: 0.522648	valid_1's l2: 0.273161
# [300]	training's rmse: 0.00236143	training's l2: 5.57636e-06	valid_1's rmse: 0.522608	valid_1's l2: 0.273119
# Fold-4 | Col-conventions | RMSE Score: 0.522543564407092
#
# Fold-4 | OOF Score: 0.5459949738933159
#
#
# [100]	training's rmse: 0.0858724	training's l2: 0.00737407	valid_1's rmse: 0.540938	valid_1's l2: 0.292614
# [200]	training's rmse: 0.0152859	training's l2: 0.000233657	valid_1's rmse: 0.53942	valid_1's l2: 0.290974
# [300]	training's rmse: 0.00302196	training's l2: 9.13223e-06	valid_1's rmse: 0.539448	valid_1's l2: 0.291004
# Fold-5 | Col-cohesion | RMSE Score: 0.5393802906440449
# [100]	training's rmse: 0.0777851	training's l2: 0.00605052	valid_1's rmse: 0.531972	valid_1's l2: 0.282994
# [200]	training's rmse: 0.0140301	training's l2: 0.000196844	valid_1's rmse: 0.531451	valid_1's l2: 0.28244
# [300]	training's rmse: 0.00269805	training's l2: 7.27946e-06	valid_1's rmse: 0.531402	valid_1's l2: 0.282388
# Fold-5 | Col-syntax | RMSE Score: 0.5313640237850059
# [100]	training's rmse: 0.07548	training's l2: 0.00569723	valid_1's rmse: 0.476411	valid_1's l2: 0.226968
# [200]	training's rmse: 0.0137235	training's l2: 0.000188334	valid_1's rmse: 0.474539	valid_1's l2: 0.225187
# [300]	training's rmse: 0.00247149	training's l2: 6.10827e-06	valid_1's rmse: 0.474513	valid_1's l2: 0.225163
# Fold-5 | Col-vocabulary | RMSE Score: 0.4744801021972818
# [100]	training's rmse: 0.0825393	training's l2: 0.00681273	valid_1's rmse: 0.55384	valid_1's l2: 0.306738
# [200]	training's rmse: 0.0132678	training's l2: 0.000176034	valid_1's rmse: 0.552068	valid_1's l2: 0.30478
# Fold-5 | Col-phraseology | RMSE Score: 0.5520416171838072
# [100]	training's rmse: 0.0871127	training's l2: 0.00758863	valid_1's rmse: 0.601352	valid_1's l2: 0.361624
# [200]	training's rmse: 0.0155614	training's l2: 0.000242157	valid_1's rmse: 0.599875	valid_1's l2: 0.35985
# [300]	training's rmse: 0.00339991	training's l2: 1.15594e-05	valid_1's rmse: 0.599636	valid_1's l2: 0.359563
# [400]	training's rmse: 0.00108346	training's l2: 1.17389e-06	valid_1's rmse: 0.59961	valid_1's l2: 0.359533
# [500]	training's rmse: 0.000467677	training's l2: 2.18722e-07	valid_1's rmse: 0.599601	valid_1's l2: 0.359521
# [600]	training's rmse: 0.000213629	training's l2: 4.56372e-08	valid_1's rmse: 0.599602	valid_1's l2: 0.359522
# Fold-5 | Col-grammar | RMSE Score: 0.5996001865166284
# [100]	training's rmse: 0.0738441	training's l2: 0.00545296	valid_1's rmse: 0.533564	valid_1's l2: 0.28469
# [200]	training's rmse: 0.0131125	training's l2: 0.000171939	valid_1's rmse: 0.531285	valid_1's l2: 0.282263
# [300]	training's rmse: 0.0023335	training's l2: 5.44523e-06	valid_1's rmse: 0.531377	valid_1's l2: 0.282361
# Fold-5 | Col-conventions | RMSE Score: 0.5312845622529764
#
# Fold-5 | OOF Score: 0.5380251304299575
#
#
# Aggregate OOF Score: 0.5416431484241553

# %% [markdown]
# ## Create submission file

# %%
y_pred_final = (y_pred_final_xgb * 0.65) + (y_pred_final_lgb * 0.35)

submission = pd.read_csv("../input/feedback-prize-english-language-learning/sample_submission.csv")

submission['cohesion'] = y_pred_final[:,0]
submission['syntax'] = y_pred_final[:,1]
submission['vocabulary'] = y_pred_final[:,2]
submission['phraseology'] = y_pred_final[:,3]
submission['grammar'] = y_pred_final[:,4]
submission['conventions'] = y_pred_final[:,5]

submission.to_csv("./submission.csv", index=False)
submission.head()
# Out:
#         text_id  cohesion    syntax  vocabulary  phraseology   grammar  \
# 0  0000C359D63E  2.888193  2.818543    3.108750     2.962972  2.629677
# 1  000BAD50D026  2.895682  2.890732    3.075280     2.897982  2.707038
# 2  00367BB2546B  3.220010  3.120133    3.304714     3.170132  3.040692
#
#    conventions
# 0     2.711964
# 1     2.890968
# 2     3.095837

# %%
## Good Day!!
